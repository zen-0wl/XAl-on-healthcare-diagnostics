# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_curve
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import shap
import numpy as np

# %%
train_data = pd.read_csv('resamp_training_data.csv')

X_train_resampled = train_data.drop(columns=['stroke'])
y_train_resampled = train_data['stroke']

test_data = pd.read_csv('resamp_test_data.csv')
X_test = test_data.drop(columns=['stroke'])
y_test = test_data['stroke']

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>Random Forest</b></font>

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=10, class_weight='balanced')

rf_model.fit(X_train_resampled, y_train_resampled)

# Predictions
y_hat_train_rf = rf_model.predict(X_train_resampled)
y_hat_test_rf = rf_model.predict(X_test)

y_hat_prob_train_rf = rf_model.predict_proba(X_train_resampled)[:, 1]
y_hat_prob_test_rf = rf_model.predict_proba(X_test)[:, 1]

# Binary threshold
binary_threshold = 0.5
y_pred_sigmoid_train_rf = (y_hat_prob_train_rf >= binary_threshold).astype(int)
y_pred_sigmoid_test_rf = (y_hat_prob_test_rf >= binary_threshold).astype(int)

# Evaluation (Train)
train_accuracy_rf = accuracy_score(y_train_resampled, y_pred_sigmoid_train_rf)
train_roc_auc_rf = roc_auc_score(y_train_resampled, y_hat_prob_train_rf)
train_f1_weighted_rf = f1_score(y_train_resampled, y_pred_sigmoid_train_rf, average='weighted')
train_precision_rf = precision_score(y_train_resampled, y_pred_sigmoid_train_rf)
train_recall_rf = recall_score(y_train_resampled, y_pred_sigmoid_train_rf)

# Evaluation (Test)
test_accuracy_rf = accuracy_score(y_test, y_pred_sigmoid_test_rf)
test_roc_auc_rf = roc_auc_score(y_test, y_hat_prob_test_rf)
test_f1_weighted_rf = f1_score(y_test, y_pred_sigmoid_test_rf, average='weighted')
test_precision_rf = precision_score(y_test, y_pred_sigmoid_test_rf)
test_recall_rf = recall_score(y_test, y_pred_sigmoid_test_rf)

# Confusion matrices with metrics
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Train Confusion Matrix
cm_train_rf = confusion_matrix(y_train_resampled, y_pred_sigmoid_train_rf)
disp_train_rf = ConfusionMatrixDisplay(confusion_matrix=cm_train_rf)
disp_train_rf.plot(cmap='Greens', ax=axes[0], colorbar=False)
axes[0].set_xlabel(f"Predicted label (Train)\n acc: {train_accuracy_rf*100:.2f}%, auc: {train_roc_auc_rf:.2f}, f1_weighted: {train_f1_weighted_rf:.2f}\n precision: {train_precision_rf:.2f}, recall: {train_recall_rf:.2f}")
axes[0].set_title('Train Confusion Matrix (Random Forest)')

# Test Confusion Matrix
cm_test_rf = confusion_matrix(y_test, y_pred_sigmoid_test_rf)
disp_test_rf = ConfusionMatrixDisplay(confusion_matrix=cm_test_rf)
disp_test_rf.plot(cmap='Greens', ax=axes[1], colorbar=False)
axes[1].set_xlabel(f"Predicted label (Test)\n acc: {test_accuracy_rf*100:.2f}%, auc: {test_roc_auc_rf:.2f}, f1_weighted: {test_f1_weighted_rf:.2f}\n precision: {test_precision_rf:.2f}, recall: {test_recall_rf:.2f}")
axes[1].set_title('Test Confusion Matrix (Random Forest)')

plt.tight_layout()
plt.show()

# ROC Curve
fpr_train_rf, tpr_train_rf, _ = roc_curve(y_train_resampled, y_hat_prob_train_rf)
fpr_test_rf, tpr_test_rf, _ = roc_curve(y_test, y_hat_prob_test_rf)

plt.figure(figsize=(8, 6))
plt.plot(fpr_train_rf, tpr_train_rf, label=f'Train ROC (AUC = {train_roc_auc_rf:.2f})', color='blue')
plt.plot(fpr_test_rf, tpr_test_rf, label=f'Test ROC (AUC = {test_roc_auc_rf:.2f})', color='darkorange')
plt.plot([0, 1], [0, 1], 'k--', alpha=0.5)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# Classification Report
print("Random Forest Performance on Test Set:")
print(classification_report(y_test, y_pred_sigmoid_test_rf))

print(f"Training Accuracy: {train_accuracy_rf:.4f}")
print(f"Training ROC AUC Score: {train_roc_auc_rf:.4f}")
print(f"Test Accuracy: {test_accuracy_rf:.4f}")
print(f"Test ROC AUC Score: {test_roc_auc_rf:.4f}")
# Out:
# Random Forest Performance on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92       960
#            1       0.19      0.44      0.26        62
#
#     accuracy                           0.85      1022
#    macro avg       0.57      0.66      0.59      1022
# weighted avg       0.91      0.85      0.88      1022
#
# Training Accuracy: 0.9800
# Training ROC AUC Score: 0.9985
# Test Accuracy: 0.8503
# Test ROC AUC Score: 0.8157

# %%
scores = cross_val_score(rf_model, X_train_resampled, y_train_resampled, cv=5, scoring='roc_auc')
print("Cross-validated AUC:", scores.mean(), "+/-", scores.std())
# Out:
# Cross-validated AUC: 0.9952288620024733 +/- 0.0033311601343513656

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>XGBoost</b></font>

# %%
xgb_model = XGBClassifier(random_state=42, max_depth=6, learning_rate=0.1, n_estimators=100)

xgb_model.fit(X_train_resampled, y_train_resampled)

# Make predictions
y_pred_xgb = xgb_model.predict(X_test)
y_pred_prob_xgb = xgb_model.predict_proba(X_test)[:, 1]

# Evaluate performance
print("XGBoost Performance:")
print(classification_report(y_test, y_pred_xgb))
print(f"Accuracy: {accuracy_score(y_test, y_pred_xgb)}")
print(f"ROC AUC Score: {roc_auc_score(y_test, y_pred_prob_xgb)}")

explainer = shap.Explainer(xgb_model, X_train_resampled)

shap_values = explainer(X_test)

# --------------------------------------
# Global Interpretability
# --------------------------------------

# Summary plot (global feature importance)
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test, plot_type="bar")  # Bar chart of mean(|SHAP|) per feature

# Beeswarm plot (distribution of feature influence)
shap.summary_plot(shap_values, X_test)  # Colored plot for positive/negative impact

# --------------------------------------
# Local Interpretability
# --------------------------------------

# Explain a single prediction (e.g., index 0)
shap.plots.waterfall(shap_values[0], max_display=10)
# Out:
# XGBoost Performance:
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       960
#            1       0.20      0.34      0.25        62
#
#     accuracy                           0.88      1022
#    macro avg       0.58      0.62      0.59      1022
# weighted avg       0.91      0.88      0.89      1022
#
# Accuracy: 0.87573385518591
# ROC AUC Score: 0.8026797715053764

# %%
scores = cross_val_score(xgb_model, X_train_resampled, y_train_resampled, cv=5, scoring='roc_auc')
print("Cross-validated AUC:", scores.mean(), "+/-", scores.std())
# Out:
# Cross-validated AUC: 0.9965350082214421 +/- 0.004251788531393475

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>Neural Network</b></font>

# %%
from sklearn.preprocessing import StandardScaler

# Scale the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Define Neural Network Architecture
nn_model = Sequential([
    Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # Output layer
])

# Compile the model
nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = nn_model.fit(X_train_scaled, y_train_resampled, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test))

# Evaluate the model
y_pred_nn_prob = nn_model.predict(X_test_scaled).ravel()
y_pred_nn = (y_pred_nn_prob > 0.5).astype(int)

print("Neural Network Performance:")
print(classification_report(y_test, y_pred_nn))
print(f"Accuracy: {accuracy_score(y_test, y_pred_nn)}")
print(f"ROC AUC Score: {roc_auc_score(y_test, y_pred_nn_prob)}")
# Out:
# c:\Users\zen\Documents\-- four\s2\FYP I\XAl-on-healthcare-diagnostics\xai\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7580 - loss: 0.5045 - val_accuracy: 0.7495 - val_loss: 0.4989
# Epoch 2/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8559 - loss: 0.3452 - val_accuracy: 0.7573 - val_loss: 0.5254
# Epoch 3/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8673 - loss: 0.3197 - val_accuracy: 0.7573 - val_loss: 0.5435
# Epoch 4/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8758 - loss: 0.2922 - val_accuracy: 0.7554 - val_loss: 0.5182
# Epoch 5/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8855 - loss: 0.2870 - val_accuracy: 0.7818 - val_loss: 0.5023
# Epoch 6/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8889 - loss: 0.2648 - val_accuracy: 0.7691 - val_loss: 0.5185
# Epoch 7/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8873 - loss: 0.2733 - val_accuracy: 0.8043 - val_loss: 0.4572
# Epoch 8/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8861 - loss: 0.2614 - val_accuracy: 0.7818 - val_loss: 0.5229
# Epoch 9/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9050 - loss: 0.2315 - val_accuracy: 0.7926 - val_loss: 0.4769
# Epoch 10/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9046 - loss: 0.2311 - val_accuracy: 0.7935 - val_loss: 0.5214
# Epoch 11/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9149 - loss: 0.2098 - val_accuracy: 0.7857 - val_loss: 0.5639
# Epoch 12/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9083 - loss: 0.2154 - val_accuracy: 0.8151 - val_loss: 0.5080
# Epoch 13/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9150 - loss: 0.2080 - val_accuracy: 0.7906 - val_loss: 0.5894
# Epoch 14/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9282 - loss: 0.1852 - val_accuracy: 0.8112 - val_loss: 0.5361
# Epoch 15/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9186 - loss: 0.1969 - val_accuracy: 0.7994 - val_loss: 0.5802
# Epoch 16/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9250 - loss: 0.1877 - val_accuracy: 0.7965 - val_loss: 0.6095
# Epoch 17/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9237 - loss: 0.1813 - val_accuracy: 0.7975 - val_loss: 0.6335
# Epoch 18/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9317 - loss: 0.1776 - val_accuracy: 0.8033 - val_loss: 0.6519
# Epoch 19/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9287 - loss: 0.1782 - val_accuracy: 0.8033 - val_loss: 0.6472
# Epoch 20/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9320 - loss: 0.1802 - val_accuracy: 0.7984 - val_loss: 0.6569
# Epoch 21/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9327 - loss: 0.1701 - val_accuracy: 0.8004 - val_loss: 0.6800
# Epoch 22/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9378 - loss: 0.1620 - val_accuracy: 0.7965 - val_loss: 0.6898
# Epoch 23/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9435 - loss: 0.1467 - val_accuracy: 0.8112 - val_loss: 0.6830
# Epoch 24/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9424 - loss: 0.1491 - val_accuracy: 0.8092 - val_loss: 0.7040
# Epoch 25/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9417 - loss: 0.1461 - val_accuracy: 0.8141 - val_loss: 0.7062
# Epoch 26/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9429 - loss: 0.1489 - val_accuracy: 0.8072 - val_loss: 0.7727
# Epoch 27/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9456 - loss: 0.1491 - val_accuracy: 0.8082 - val_loss: 0.7690
# Epoch 28/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9481 - loss: 0.1356 - val_accuracy: 0.8112 - val_loss: 0.7464
# Epoch 29/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9504 - loss: 0.1303 - val_accuracy: 0.8239 - val_loss: 0.6996
# Epoch 30/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9456 - loss: 0.1362 - val_accuracy: 0.8082 - val_loss: 0.8011
# Epoch 31/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9510 - loss: 0.1254 - val_accuracy: 0.8160 - val_loss: 0.8264
# Epoch 32/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9572 - loss: 0.1190 - val_accuracy: 0.8366 - val_loss: 0.7714
# Epoch 33/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9457 - loss: 0.1365 - val_accuracy: 0.8121 - val_loss: 0.8486
# Epoch 34/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9512 - loss: 0.1253 - val_accuracy: 0.8249 - val_loss: 0.8558
# Epoch 35/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9531 - loss: 0.1264 - val_accuracy: 0.8200 - val_loss: 0.8225
# Epoch 36/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9575 - loss: 0.1214 - val_accuracy: 0.8121 - val_loss: 0.8859
# Epoch 37/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9534 - loss: 0.1198 - val_accuracy: 0.8160 - val_loss: 0.8617
# Epoch 38/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9562 - loss: 0.1173 - val_accuracy: 0.8337 - val_loss: 0.8452
# Epoch 39/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9604 - loss: 0.1167 - val_accuracy: 0.8337 - val_loss: 0.8557
# Epoch 40/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9583 - loss: 0.1078 - val_accuracy: 0.8337 - val_loss: 0.8786
# Epoch 41/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9624 - loss: 0.1026 - val_accuracy: 0.8112 - val_loss: 0.9833
# Epoch 42/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9528 - loss: 0.1156 - val_accuracy: 0.8200 - val_loss: 0.9446
# Epoch 43/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9629 - loss: 0.1045 - val_accuracy: 0.8219 - val_loss: 0.9863
# Epoch 44/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9627 - loss: 0.0962 - val_accuracy: 0.8209 - val_loss: 0.9931
# Epoch 45/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.1032 - val_accuracy: 0.8180 - val_loss: 0.9715
# Epoch 46/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9580 - loss: 0.1100 - val_accuracy: 0.8209 - val_loss: 0.9395
# Epoch 47/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9642 - loss: 0.0956 - val_accuracy: 0.8190 - val_loss: 0.9823
# Epoch 48/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9614 - loss: 0.1039 - val_accuracy: 0.8209 - val_loss: 1.0201
# Epoch 49/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9589 - loss: 0.1090 - val_accuracy: 0.8239 - val_loss: 1.0305
# Epoch 50/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9597 - loss: 0.0952 - val_accuracy: 0.8170 - val_loss: 1.0384
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Neural Network Performance:
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       960
#            1       0.13      0.37      0.20        62
#
#     accuracy                           0.82      1022
#    macro avg       0.54      0.61      0.55      1022
# weighted avg       0.90      0.82      0.85      1022
#
# Accuracy: 0.8170254403131115
# ROC AUC Score: 0.764432123655914

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>Validation Accuracy & Loss</b></font>

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Neural Network Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Neural Network Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>Visualisations</b></font>

# %%
# Random Forest
rf_importances = pd.DataFrame({
    'Feature': X_train_resampled.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=True)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=rf_importances, palette='viridis')

# Add values on bars
for index, value in enumerate(rf_importances['Importance']):
    plt.text(value + 0.001, index, f'{value:.3f}', va='center')

plt.title("Random Forest Feature Importance", fontsize=14)
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# XGBoost
xgb_importances = pd.DataFrame({
    'Feature': X_train_resampled.columns,
    'Importance': xgb_model.feature_importances_
}).sort_values(by='Importance', ascending=True)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=xgb_importances, palette='magma')

# Add values on bars
for index, value in enumerate(xgb_importances['Importance']):
    plt.text(value + 0.001, index, f'{value:.3f}', va='center')

plt.title("XGBoost Feature Importance", fontsize=14)
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# # Neural Network
# weights = nn_model.layers[0].get_weights()[0]  # weights of the first layer
# biases = nn_model.layers[0].get_weights()[1]  # biases of the first layer (if needed)

# plt.figure(figsize=(10, 6))
# plt.imshow(weights, cmap='hot', interpolation='nearest')
# plt.colorbar()
# plt.title("Neural Network Weights (First Layer)")
# plt.show()
# Out:
# C:\Users\zen\AppData\Local\Temp\ipykernel_23736\1043613243.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=rf_importances, palette='viridis')
# C:\Users\zen\AppData\Local\Temp\ipykernel_23736\1043613243.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=xgb_importances, palette='magma')

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>Save results</b></font>

# %%
# Compare model results
results = {
    "Model": ["Random Forest", "XGBoost", "Neural Network"],
    "Accuracy": [accuracy_score(y_test, y_pred_sigmoid_test_rf), accuracy_score(y_test, y_pred_xgb), accuracy_score(y_test, y_pred_nn)],
    "ROC AUC": [roc_auc_score(y_test, y_hat_prob_test_rf), roc_auc_score(y_test, y_pred_prob_xgb), roc_auc_score(y_test, y_pred_nn_prob)]
}

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#             Model  Accuracy   ROC AUC
# 0   Random Forest  0.850294  0.815701
# 1         XGBoost  0.875734  0.802680
# 2  Neural Network  0.817025  0.764432

# %% [markdown]
# <font color="bluegrey" size=+1.0><b>Save models</b></font>

# %%
from joblib import dump

dump(rf_model, 'random_forest_model.pkl')
dump(xgb_model, 'xgboost_model.pkl')
dump(nn_model, 'neural_network_model.pkl')
print("Successfully saved the models.")
# Out:
# Successfully saved the models.
